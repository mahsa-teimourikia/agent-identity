# %% [markdown]
# # Identity context
# Validate issuer, audience, tenant, and expiry before a tool call.
#
# ## Reflection
# What should happen when the issuer is valid but the audience is another API?

# %%
import runpy
runpy.run_path('../beginner/01_identity_context.py', run_name='__main__')
