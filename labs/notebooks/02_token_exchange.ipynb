# %% [markdown]
# # Safe token exchange
# Down-scope a parent grant for one audience and bound its lifetime.
#
# ## Reflection
# Why is an audience claim as important as a scope?
#
# ## Reflection

# %%
import runpy
runpy.run_path('../intermediate/01_token_exchange.py', run_name='__main__')
